# %% [markdown]
# HELLO again welcome back to my 4th blog post.
# This week I will run some more segmentation based experiments
#
# First we read in our image and turn it into grayscale...

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# Read in carotid image
carotid_img = cv2.imread("Carotid.jpg")
grayscale = cv2.cvtColor(carotid_img, cv2.COLOR_BGR2GRAY)
                         
# Show Images
fig = plt.figure(figsize=(15,20))
ax1 = fig.add_subplot(2,2,1)
imgplot = plt.imshow(carotid_img)
ax1.set_title("Original")

ax2 = fig.add_subplot(222)
imgplot2 = plt.imshow(grayscale,cmap='gray')
ax2.set_title("Grayscale")
plt.show()

# %% [markdown]
# We then play apply Adaptive Thresholding as per the last post on the images

# %%
# Adaptive Thresholding
B1 = cv2.adaptiveThreshold(grayscale, maxValue = 255, adaptiveMethod = cv2.ADAPTIVE_THRESH_MEAN_C, thresholdType = cv2.THRESH_BINARY_INV, blockSize = 5,C = 5)

# Show Images
fig = plt.figure(figsize=(15,20))
ax1 = fig.add_subplot(2,2,1)
imgplot = plt.imshow(B1,'gray')
ax1.set_title("Adaptive Threshold")
plt.show()

# %% [markdown]
# We can then try to denoise this image.
#
# First we choose our kernel which acts as our "razor"
# This will allow us to cut different objects in our image
#
# We then apply Opening which consists of erosion followed by dilation to get rid of alot of the detail in the image

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(2,2))
mask = cv2.morphologyEx(B1,cv2.MORPH_OPEN,kernel)
mask = cv2.erode(mask,kernel,iterations=1)

# Show Images
fig = plt.figure(figsize=(15,20))
ax1 = fig.add_subplot(2,2,1)
imgplot = plt.imshow(mask,'gray')
ax1.set_title("Opening")
plt.show()
